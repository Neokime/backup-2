# %%
import pandas as pd
list = [1,2,3,4,5]
s = pd.Series(list)

print(s)
print(s.index)
print(s.values)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# RangeIndex(start=0, stop=5, step=1)
# [1 2 3 4 5]

# %%
s2=pd.Series(list,index=['a','b','c','d','e'])
print(s2)
print(s2.index)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
